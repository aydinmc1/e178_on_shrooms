# %% [markdown]
# ## Hello there! Here's an example jupyter notebook.
#
# We can start coding here. Feel free to add more files or folders or whatever for organization.
#
# It would be great to have a processed_data folder or something too, especially after the work Thomas and Eddy already did cleaning a bunch of our data.

# %%
# Here's some code

print("Welcome to the E178_ON_SHROOMS project!")
